# %% [markdown]
# # Pandas

# %% [markdown]
# ## Task 1
#
# You should import the necessary libraries. You will use `numpy` and `pandas` libraries.
#
#
# > Don't forget to import `numpy`, and `pandas` in short form.

# %%
# Write your code here
import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 2
#
# Create a `DataFrame` from the given dictionary `data`.

# %%
data = {
    "Name": ["John", "Emily", "Ryan"],
    "Age": [16, 28, 22],
    "City": ["New York", "Los Angeles", "Chicago"],
}

# write your code here
pd_data = pd.DataFrame(
    {
        "Name": ["John", "Emily", "Ryan"],
        "Age": [16, 28, 22],
        "City": ["New York", "Los Angeles", "Chicago"],
    }
)
print(pd_data)
# Out:
#     Name  Age         City
# 0   John   16     New York
# 1  Emily   28  Los Angeles
# 2   Ryan   22      Chicago

# %% [markdown]
# ## Task 3
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 3.1
# Display all data for `Age` column for the DataFrame you created in the previous task.

# %%
# Write your code here
print(pd_data["Age"])
# Out:
# 0    16
# 1    28
# 2    22
# Name: Age, dtype: int64

# %% [markdown]
# ### Task 3.2
#
# Add `Salary` column to the `DataFrame` with the values `[50000, 60000, 45000]`.

# %%
# Write your code here
pd_data["Salary"] = [50000, 60000, 45000]
print(pd_data)
# Out:
#     Name  Age         City  Salary
# 0   John   16     New York   50000
# 1  Emily   28  Los Angeles   60000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ### Task 3.3
#
# Filter the `DataFrame` to show only the rows with the `Age` greater than 18.

# %%
# Write your code here
print(pd_data[pd_data["Age"] > 18])
# Out:
#     Name  Age         City  Salary
# 1  Emily   28  Los Angeles   60000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ## Task 4
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 4.1
#
# Add new calculated field `Birth year`;

# %%
# Write your code here
current_year = 2025
pd_data["Birth year"] = current_year - pd_data["Age"]
print(pd_data)
# Out:
#     Name  Age         City  Salary  Birth year
# 0   John   16     New York   50000        2009
# 1  Emily   28  Los Angeles   60000        1997
# 2   Ryan   22      Chicago   45000        2003

# %% [markdown]
# ### Task 4.2
#
# Add new calculated field `Average age`.

# %%
# Write your code here
# pd_data["Average age"] = np.mean(pd_data["Age"])
pd_data["Average age"] = pd_data["Age"].mean()
print(pd_data)
# Out:
#     Name  Age         City  Salary  Birth year  Average age
# 0   John   16     New York   50000        2009         22.0
# 1  Emily   28  Los Angeles   60000        1997         22.0
# 2   Ryan   22      Chicago   45000        2003         22.0

# %% [markdown]
# ### Task 4.3
#
# Calculate absolute difference between `Age` and `Average age`.

# %%
# Write your code here
pd_data["Absdolute difference"] = abs(pd_data["Age"] - pd_data["Average age"])
print(pd_data)
# Out:
#     Name  Age         City  Salary  Birth year  Average age  \
# 0   John   16     New York   50000        2009         22.0
# 1  Emily   28  Los Angeles   60000        1997         22.0
# 2   Ryan   22      Chicago   45000        2003         22.0
#
#    Absdolute difference
# 0                   6.0
# 1                   6.0
# 2                   0.0

# %% [markdown]
# ## Task 5
#
# Complete the following tasks described below.

# %% [markdown]
# ### Task 5.1
#
# You have two dictionaries `data1` and `data2`. Create two `DataFrame` objects from these dictionaries. Then, `concatenate`, and `merge` these two `DataFrame` objects into one `DataFrame` object, and see the difference.

# %%
# Data
data1 = {'Name': ['John', 'Emily', 'Ryan'],
         'Age': [25, 28, 22]}
data2 = {'Name': ['Emily', 'Ryan', 'Mike'],
         'City': ['Los Angeles', 'Chicago', 'Houston']}

# create DataFrame objects
pd_data1 = pd.DataFrame({'Name': ['John', 'Emily', 'Ryan'],
                         'Age': [25, 28, 22]})
pd_data2 = pd.DataFrame({'Name': ['Emily', 'Ryan', 'Mike'],
                         'City': ['Los Angeles', 'Chicago', 'Houston']})

print(pd_data1, "\n\n", pd_data2)
# Out:
#     Name  Age
# 0   John   25
# 1  Emily   28
# 2   Ryan   22
#
#      Name         City
# 0  Emily  Los Angeles
# 1   Ryan      Chicago
# 2   Mike      Houston

# %%
# merge
merge_result = pd.merge(pd_data1, pd_data2, how="outer")
print(merge_result)
# Out:
#     Name   Age         City
# 0  Emily  28.0  Los Angeles
# 1   John  25.0          NaN
# 2   Mike   NaN      Houston
# 3   Ryan  22.0      Chicago

# %%
# concatenate
concatenate_result = pd.concat([pd_data1, pd_data2])
print(concatenate_result)
# Out:
#     Name   Age         City
# 0   John  25.0          NaN
# 1  Emily  28.0          NaN
# 2   Ryan  22.0          NaN
# 0  Emily   NaN  Los Angeles
# 1   Ryan   NaN      Chicago
# 2   Mike   NaN      Houston

# %% [markdown]
# ### Task 5.2
#
# You have two `Series` objects `s1` and `s2`. Make default mathematical operations on these two `Series` objects. Such as `+`, `-`, `*`, `/`, `**`, `//`, `%`. Also, filter `s1` and print only even numbers, and `s2` only with odd numbers.

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([6, 7, 8, 9, 10])

# %%
# use + operator here
plus_data = pd.Series(s1 + s2)
print(plus_data)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %%
# use - operator here
minus_data = pd.Series(s1 - s2)
print(minus_data)
# Out:
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64

# %%
# use * operator here
multiplication_data = pd.Series(s1 * s2)
print(multiplication_data)
# Out:
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64

# %%
# use / operator here
division_data = pd.Series(s1 / s2)
print(division_data)
# Out:
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %%
# use ** operator here
sqrt_data = pd.Series(s1 ** s2)
print(sqrt_data)
# Out:
# 0          1
# 1        128
# 2       6561
# 3     262144
# 4    9765625
# dtype: int64

# %%
# use // operator here
floor_division_data = pd.Series(s1 // s2)
print(floor_division_data)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
# use % operator here
modulus_data = pd.Series(s1 % s2)
print(modulus_data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# filter s1 here
filtered_s1 = s1[s1 % 2 == 0]
print(filtered_s1)
# Out:
# 1    2
# 3    4
# dtype: int64

# %%
# filter s2 here
filtered_s2 = s2[s2 % 2 == 1]
print(filtered_s2)
# Out:
# 1    7
# 3    9
# dtype: int64

# %% [markdown]
# ### Task 5.3
#
# You have a `Serias` object `s`. Make the following operations on this `Series` object:
#
# * make all words in uppercase without loops;
# * get length of each word without loops.

# %%
s = pd.Series(["numpy", "pandas", "matplotlib"])

# %%
# make all words in uppercase
print(s.str.upper())
# Out:
# 0         NUMPY
# 1        PANDAS
# 2    MATPLOTLIB
# dtype: object

# %%
# get length of each word
print(s.str.len())
# Out:
# 0     5
# 1     6
# 2    10
# dtype: int64

# %% [markdown]
# ## Task 6 Optional
#
# You have a large dataset consisting of a series of numbers. Your task is to calculate the moving average of the series using a window of `5` elements. The moving average is the average of a set of consecutive values in the series, where the window `slides` through the series to compute the average at each position. The goal is to calculate the moving average efficiently and accurately. Also, compare time performance of Python and Pandas solutions.
#
# > Please, note: If you get `nan` while calculating the moving average, you should remove it from the result. Pandas solution should take 1-2 lines of code.

# %% [markdown]
# ### Python Solution
#
# In the Python solution, a large dataset is generated using random numbers. The moving average is computed by iterating over the dataset using a loop. At each position, a window of 5 elements is created, and the average is calculated by summing the values in the window and dividing by 5.

# %%
import random


def unknown_signature():
    # Generate a large dataset
    data = [random.randint(1, 100) for _ in range(10000000)]

    # Calculate the moving average with a window of 5
    moving_averages = []
    for i in range(4, len(data)):
        window = data[i - 4: i + 1]
        average = sum(window) / 5
        moving_averages.append(average)
    return moving_averages[:10]

# %time unknown_signature()
# Out:
# CPU times: user 13 s, sys: 197 ms, total: 13.2 s
# Wall time: 13.4 s
# [47.2, 37.2, 38.4, 38.4, 29.0, 28.0, 42.0, 47.4, 58.4, 58.8]

# %% [markdown]
# ### Solution using Pandas and Numpy

# %%
# write your code here
pd_random_data = pd.Series([random.randint(1, 100) for _ in range(10000000)])
moving_averages = pd_random_data.rolling(window=5).mean().tail(10)
# %time print(moving_averages)
# Out:
# 9999990    36.0
# 9999991    32.4
# 9999992    27.6
# 9999993    28.6
# 9999994    30.8
# 9999995    42.6
# 9999996    44.0
# 9999997    56.8
# 9999998    70.0
# 9999999    62.4
# dtype: float64
# CPU times: user 1.83 ms, sys: 1.59 ms, total: 3.41 ms
# Wall time: 6.39 ms
